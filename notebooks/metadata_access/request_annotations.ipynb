# %% [markdown]
# ## Requesting Annotations by Reference Designator
#
# In this example we show how to request all annotations made for the Cabled Array International District Vent Field 2 (RS03INT2) Medium-Power JBox (MJ03D) Bottom Pressure and Tilt (06-BOTPTA303) instrument. The same technique applies to all instruments (Reference Designators) on the OOI.

# %%
import requests
import json
import netCDF4 as nc
import datetime
import pandas as pd

# %% [markdown]
# Below we have entered credential for a default user. These should work, unless they have been reset.
# Alternatively, you can login in at https://ooinet.oceanobservatories.org/ and obtain a API username and API token under your profile (top right corner).

# %%
username = 'OOIAPI-D8S960UXPK4K03'
token = 'IXL48EQ2XY'

# %% [markdown]
# Specify the reference designator you are looking for. For further information on finding reference designators for other instruments and be found via the data team portal at http://ooi.visualocean.net.

# %%
refdes = 'RS01SBPS-SF01A-4A-NUTNRA101'

# %% [markdown]
# The next step specifies to return all annotations between 2012 and now. Time stamps are converted from a string to milliseconds since 1970-01-01.

# %%
beginDT = int(nc.date2num(datetime.datetime.strptime("2012-01-01T01:00:01Z",'%Y-%m-%dT%H:%M:%SZ'),'seconds since 1970-01-01')*1000)
endDT = int(nc.date2num(datetime.datetime.utcnow(),'seconds since 1970-01-01')*1000)

# %% [markdown]
# Now we are ready to build the data request url and send the request.

# %%
anno_base_url = 'https://ooinet.oceanobservatories.org/api/m2m/12580/anno/find?' # base url and port for annotations

params = { # define parameters
    'beginDT':beginDT,
    'endDT':endDT,
    'refdes':refdes,
}

r = requests.get(anno_base_url, params=params,auth=(username, token)) # send data request

data = pd.read_json(json.dumps(r.json())) # convert json response to pandas dataframe
data
# Out:
#                @class                                         annotation  \
# 0   .AnnotationRecord  A brief violent storm caused loss of power to ...
# 1   .AnnotationRecord  SF01A powered down on 3/21/2018 due to oil lea...
# 2   .AnnotationRecord  This instrument was deployed with onboard proc...
# 3   .AnnotationRecord  Note: PFE down. HVPS1 MOV explosion, 800A brea...
# 4   .AnnotationRecord  Note: PNWGP Portland <-> Seattle outage. Possi...
# 5   .AnnotationRecord  Note: Intermittent partial data loss due to st...
# 6   .AnnotationRecord  Note: PNWGP outage due to City of Seattle fibe...
# 7   .AnnotationRecord  Note: Network issues due to fire that damaged ...
# 8   .AnnotationRecord  Note: Four 1-minute outages between Portland a...
# 9   .AnnotationRecord  Note: Unexplained loss of power at Pittock Bui...
# 10  .AnnotationRecord  Note: Outage during major utility power failur...
# 11  .AnnotationRecord  Note: Fiber break between Portland and Seattle...
# 12  .AnnotationRecord  Note: Fiber break between Portland and Pacific...
# 13  .AnnotationRecord  Note: Corvalis data center lost power. Possibl...
# 14  .AnnotationRecord  Note: Fiber break in Portland due to train cra...
# 15  .AnnotationRecord  Note: Network outage during major Seattle util...
# 16  .AnnotationRecord  Note: Lightning strike in Pacific City led to ...
# 17  .AnnotationRecord  Note: On Sunday, January 29th, the Shallow Pro...
# 18  .AnnotationRecord  Note: Outage during PNWGP 1-hour router-mainte...
# 19  .AnnotationRecord  Note: On Wednesday, February 15, power to the ...
#
#           beginDT         endDT  exclusionFlag    id    method   node  \
# 0   1516330801000  1.516388e+12          False   319      None   None
# 1   1521591180000           NaN          False  1369      None  SF01A
# 2   1436394121974  1.454638e+12          False  1370  streamed  SF01A
# 3   1417981500000  1.418688e+12          False  1248      None   None
# 4   1420615920000  1.420618e+12          False  1250      None   None
# 5   1422662400000  1.423008e+12          False  1251      None   None
# 6   1426947000000  1.426998e+12          False  1256      None   None
# 7   1434153600000  1.434386e+12          False  1259      None   None
# 8   1452147000000  1.452150e+12          False  1266      None   None
# 9   1468291980000  1.468295e+12          False  1276      None   None
# 10  1440806400000  1.440808e+12          False  1262      None   None
# 11  1457651160000  1.457689e+12          False  1268      None   None
# 12  1463761980000  1.463767e+12          False  1274      None   None
# 13  1481997600000  1.482001e+12          False  1281      None   None
# 14  1482371400000  1.482497e+12          False  1282      None   None
# 15  1483905480000  1.483912e+12          False  1283      None   None
# 16  1483986720000  1.483997e+12          False  1286      None   None
# 17  1485648000000  1.501805e+12          False  1287      None  SF01A
# 18  1486472400000  1.486480e+12          False  1288      None   None
# 19  1487169786000  1.487179e+12          False  1289      None   None
#
#      parameters           qcFlag        sensor                       source  \
# 0            []  not_operational          None  friedrich.knuth@rutgers.edu
# 1            []  not_operational          None                         None
# 2   [2320, 315]          suspect  4A-NUTNRA101  friedrich.knuth@rutgers.edu
# 3            []             None          None     knuth@marine.rutgers.edu
# 4            []             None          None     knuth@marine.rutgers.edu
# 5            []             None          None     knuth@marine.rutgers.edu
# 6            []             None          None     knuth@marine.rutgers.edu
# 7            []             None          None     knuth@marine.rutgers.edu
# 8            []             None          None     knuth@marine.rutgers.edu
# 9            []             None          None     knuth@marine.rutgers.edu
# 10           []             None          None     knuth@marine.rutgers.edu
# 11           []             None          None     knuth@marine.rutgers.edu
# 12           []             None          None     knuth@marine.rutgers.edu
# 13           []             None          None     knuth@marine.rutgers.edu
# 14           []             None          None     knuth@marine.rutgers.edu
# 15           []             None          None     knuth@marine.rutgers.edu
# 16           []             None          None     knuth@marine.rutgers.edu
# 17           []             None          None     knuth@marine.rutgers.edu
# 18           []             None          None     knuth@marine.rutgers.edu
# 19           []             None          None     knuth@marine.rutgers.edu
#
#             stream   subsite
# 0             None  RS01SBPS
# 1             None  RS01SBPS
# 2   nutnr_a_sample  RS01SBPS
# 3             None  RS01SBPS
# 4             None  RS01SBPS
# 5             None  RS01SBPS
# 6             None  RS01SBPS
# 7             None  RS01SBPS
# 8             None  RS01SBPS
# 9             None  RS01SBPS
# 10            None  RS01SBPS
# 11            None  RS01SBPS
# 12            None  RS01SBPS
# 13            None  RS01SBPS
# 14            None  RS01SBPS
# 15            None  RS01SBPS
# 16            None  RS01SBPS
# 17            None  RS01SBPS
# 18            None  RS01SBPS
# 19            None  RS01SBPS

# %% [markdown]
# As mentioned above, time stamps from the annotations API are handled in milliseconds since 1970-01-01. Let's create a function to convert them back to human readable time stamps and convert the millisecond time stamps in the data frame.

# %%
def convert_time(time_stamp):
    try: 
        time_stamp = (int(time_stamp)) / 1000
        time_stamp = nc.num2date(time_stamp,'seconds since 1970-01-01')
    except:
        pass
    return time_stamp

# convert time stamps
data['beginDT'] = data['beginDT'].apply(convert_time)
data['endDT'] = data['endDT'].apply(convert_time)

# %% [markdown]
# Now, let's select and print all the annotations that were made at the parameter level, by excluding any empty parameter level annotations. In this case, there is only one annotation that meets this criteria.

# %%
param_anno = data[data['parameters'].str.len() != 0]

for i in range(len((param_anno['annotation'].values))):
    print('start time:', param_anno['beginDT'].iloc[i])
    print('end time:', param_anno['endDT'].iloc[i], '\n')
    print('affected parameters:', param_anno['parameters'].iloc[i], '\n')
    print(param_anno['annotation'].iloc[i],'\n')
# Out:
# start time: 2015-07-08 22:22:01.974000
# end time: 2016-02-05 02:00:11.695000
#
# affected parameters: [2320, 315]
#
# This instrument was deployed with onboard processing set to freshwater mode leading to an invalid L1 Dissolved Nitrate Concentration data product. The L2 version of the data product is unaffected by that onboard setting as it is calculated using the L0 data with salinity and temperature from a co-located CTD. Redmine: 8659

# %% [markdown]
# ## Known issue 1: it is hard to know what parameters are affected, just based on being given the parameter PD number.
# You can cross reference the PD numbers with preload as follows, but this is far from optimal. For this reason, and until a solution is implemented, it is advised to include the affected parameter names in the annotation whenever making an annotation at the parameter level.

# %%
preload = 'https://raw.githubusercontent.com/oceanobservatories/preload-database/master/csv/ParameterDefs.csv'
pre_l = pd.read_csv(preload)

# %%
pre_l[['name','id','description']][pre_l['id'] == 'PD2320']
# Out:
#                            name      id          description
# 1815  nutnr_nitrogen_in_nitrate  PD2320  Nitrogen in Nitrate

# %%
pre_l[['name','id','description']][pre_l['id'] == 'PD315']
# Out:
#                       name     id  \
# 225  nitrate_concentration  PD315
#
#                                            description
# 225  Dissolved Nitrate Concentration, uncorrected f...

# %% [markdown]
# ## Known issue 2: annotation time stamps are returned as milliseconds since 1970, while data time stamps are returned as seconds since 1900?
# The system should use consistent time stamps for all data and metadata types. There is no Redmine ticket on this as of yet.
